# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,y=make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1, noise=80,random_state=13)

# %%
import matplotlib.pyplot as plt

# %%
plt.title('make liner regression')
plt.scatter(X,y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# 26.15963284313262

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red')

# %%
#  Lets apply Gradient Descent assuming slope is constant m = 78.35
# # and let's assume the starting value for intercept b = 0
# y_pred = ((78.35 * X) + 100).reshape(4)

# %% [markdown]
# Lets apply Gradinet descent assuming slope is constant m=78.35
#
# and let's assume the staring value for intecept b=0

# %%
import numpy as np
b=500

# %%
y_pred=((78.35*X)+b).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='Model')
plt.plot(X,y_pred,color='blue',label='b=0')
plt.legend()
plt.show()

# %% [markdown]
# # calculating loss function

# %%
m=78.35
b=100

# %%
loss_slope=-2*np.sum(y-m*X.ravel()-b)

# %%
loss_slope
# Out:
# 590.7223659179078

# %% [markdown]
# <!-- # Lets take learning rate = 0.1
# lr = 0.1
#
# step_size = loss_slope*lr
# step_size -->

# %% [markdown]
# let's learning rate 0.1

# %%
lr=0.1
step_size=loss_slope*lr

# %%
step_size
# Out:
# 59.072236591790784

# %% [markdown]
# # calculate a new intercept

# %%
b=b-step_size

# %%
b
# Out:
# 40.927763408209216

# %%
y_pred1=((78.35*X)+b).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='green',label='model_1')
plt.plot(X,y_pred,color='gray',label='model_2')
plt.plot(X,y_pred1,color='red',label='model_3')
plt.legend()
plt.show()

# %%
loss_slope=-2*np.sum(y-m*X.ravel()-b)

# %%
loss_slope
# Out:
# 118.14447318358157

# %%
step_size=loss_slope*lr

# %%
step_size
# Out:
# 11.814447318358157

# %%
b=b-step_size

# %%
b
# Out:
# 29.11331608985106

# %%
y_pred2=((78.35+X)+b).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='first_model')
plt.plot(X,y_pred,color='gray',label='2nd model')
plt.plot(X,y_pred1,color='blue',label='3rd model')
plt.plot(X,y_pred2,color='green',label='4th model')
plt.legend()
plt.show()

# %%
loss_slope=-2*np.sum(y-m*X.ravel()-b)

# %%
loss_slope
# Out:
# 23.62889463671634

# %%
step_size=loss_slope*lr

# %%
step_size
# Out:
# 2.362889463671634

# %%
b=b-step_size

# %%
b
# Out:
# 26.750426626179426

# %%
y_pred_3=((78.35*X)+b).reshape(4)

# %%
plt.figure(figsize=(15,15))
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='linear_model')
plt.plot(X,y_pred,color='green',label='green_pred')
plt.plot(X,y_pred1,color='gray',label='gray_pred1')
plt.plot(X,y_pred2,color='blue',label='blue_pred2')
plt.plot(X,y_pred_3,color='orange',label='black_pred3')
plt.legend()
plt.show()

# %%
# b = -100
# m = 78.35
# lr = 0.01

# epochs = 100

# for i in range(epochs):
#   loss_slope = -2 * np.sum(y - m*X.ravel() - b)
#   b = b - (lr * loss_slope)

#   y_pred = m * X + b

#   plt.plot(X,y_pred)

# plt.scatter(X,y)

# %%
b=-100
m=78.35
lr=0.001

# %%
epochs=100

for i in range(epochs):
    loss_slope=-2*np.sum(y-m*X.ravel()-b)
    step_size=loss_slope*lr
    b=b-step_size
    y_pred4=m*X+b
    plt.plot(X,y_pred4)
plt.scatter
# Out:
# <function matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, *, edgecolors=None, plotnonfinite=False, data=None, **kwargs)>
